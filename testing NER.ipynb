# %% [markdown]
# ## Reading the 3 pdfs that we will use as training data

# %%
pip install pypdf
# Out:
# Requirement already satisfied: pypdf in c:\users\ghaza\anaconda3\lib\site-packages (3.5.0)
# Requirement already satisfied: typing_extensions>=3.10.0.0 in c:\users\ghaza\anaconda3\lib\site-packages (from pypdf) (4.4.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pypdf import PdfReader

reader = PdfReader("CEG4166Syllabus.pdf")
reader2 = PdfReader("CSI3131 Course Syllabus.pdf")
reader3 = PdfReader("CEG3185A _ course_outline.pdf")

def returnText(reader):
    number_of_pages = len(reader.pages)
    text = ""
    for i in range(number_of_pages):
      page = reader.pages[i]
      text += page.extract_text()
    return text

# %%
text1 = returnText(reader)
text2 = returnText(reader2)
text3 = returnText(reader3)

# %% [markdown]
# ## Training NER

# %%
# Load Packages
from __future__ import unicode_literals, print_function

import plac #  wrapper over argparse
import random
from pathlib import Path
import spacy
from tqdm import tqdm # loading bar

# %%
from spacy.cli.download import download
download(model="en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp1 = spacy.load('en_core_web_sm')

# %%
docx = nlp1(text1)

# %%
for token in docx.ents:
    print(token.text, token.label_)
# Out:
# EECS ORG
# École de science informatique et
# de génie PERSON
# SIGE ORG
# 3 CARDINAL
# 1.5 DATE
# 3 CARDINAL
# Winter 202 DATE
# 3 CARDINAL
# Instructor ORG
# Gilbert Arbez PERSON
# MS Teams ORG
# 613 CARDINAL
# 6315 DATE
# 1 CARDINAL
# fed ORG
# hese CARDINAL
# 2 CARDINAL
# weekly DATE
# lea der PERSON
# 2/9 3 CARDINAL
# 4 CARDINAL
# SCHEDULE ORG
# Mondays 13h00 to 14h30
# Wednesdays 11h30 to DATE
# Mondays 17h30 DATE
# Tuesdays 11h30 to DATE
# Friday 14h30 to 17h20 DATE
# Thursday 13h00 to 15h50 DATE
# only one CARDINAL
# Tuesdays 14h 30 to 1 5h50 DATE
# Wednesdays  11h30 DATE
# Saturdays  11h30 to 14h 20
# Wednesdays  16h00 to 1 8h50 DATE
# only one CARDINAL
# 5 CARDINAL
# Brightspace ORG
# 6-TEACHING QUANTITY
# Haopeng Wang PERSON
# Palwasha Waheed Shaikh PERSON
# Edwin Thomas PERSON
# Abhillash Paal ORG
# two CARDINAL
# 7 CARDINAL
# LECTURE PERSON
# Phillip Laplante PERSON
# Tools PERSON
# Practitioner PERSON
# Wiley PERSON
# 4th ORDINAL
# 2012 DATE
# 3/9 8 CARDINAL
# Brightspace ORG
# 4 CARDINAL
# Two CARDINAL
# 2 CARDINAL
# 10 CARDINAL
# 4 CARDINAL
# 11 CARDINAL
# Brigh NORP
# 4 CARDINAL
# Notes PRODUCT
# first ORDINAL
# two CARDINAL
# PDF ORG
# PDF ORG
# Composer PERSON
# Sprint ORG
# API HTML ORG
# Doxygen ORG
# Doxygen ORG
# Rubric ORG
# Brightspace ORG
# Brigthspace GPE
# first ORDINAL
# Sunday , March 5 DATE
# Final Exam ORG
# University ORG
# 12 CARDINAL
# 13 CARDINAL
# 50% PERCENT
# Exam ORG
# 15% PERCENT
# Final Exam ORG
# 35% PERCENT
# 4/9 14 CARDINAL
# 55% PERCENT
# 15 CARDINAL
# Attendance PERSON
# 80% PERCENT
# 16 CARDINAL
# F PRODUCT
# second ORDINAL
# the Faculty of Engineering ORG
# the University of Ottawa’s ORG
# 9.4 CARDINAL
# 9.5 DATE
# 9.6 CARDINAL
# 14.2 DATE
# 14.3 CARDINAL
# the University of Ottawa’s ORG
# the academic year DATE
# University of Ottawa ORG
# informat ORG
# 5/9 17 CARDINAL
# Brightspace ORG
# The University of Ottawa ORG
# Access
# Service ORG
# The Student Academic Success Service ORG
# 6/9 19 CARDINAL
# 1 CARDINAL
# 1.1 CARDINAL
# 2 CARDINAL
# 2.1 CARDINAL
# 3 CARDINAL
# 3.1 CARDINAL
# 4.1 CARDINAL
# 4.3 MONEY
# 5 CARDINAL
# 5.2 CARDINAL
# 6 CARDINAL
# 7.1 CARDINAL
# 7.2 CARDINAL
# 7.3 CARDINAL
# weekly DATE
# 8 CARDINAL
# 8.1 CARDINAL
# 9 CARDINAL
# 10 CARDINAL
# Ethics ORG
# 11 CARDINAL
# 11.1 CARDINAL
# 12 CARDINAL
# 20 CARDINAL
# 8/9 CARDINAL
# Personal Ethics Agreement Concerning University Assignments ORG
# the University of Ottawa ORG
# the University of Ottawa ORG
# Signature      Date
#
#
#   9/9 Personal Ethics Agreement Concerning University Assignments
#
# Group Project WORK_OF_ART
# the University of Ottawa ORG
# the  University of Ottawa ORG
# Signature      Date
#
#
#  WORK_OF_ART
# Signature      Date
#
#
#  WORK_OF_ART
# Signature      Date
#
#
#  WORK_OF_ART
# Signature      Date
#
#
#  WORK_OF_ART
# Signature      Date
#
#   WORK_OF_ART

# %%
import re
#1st syllabus
d1 = re.search("Deliverable 1 – Draft Design.",text1)
d1s = d1.start()
d1e = d1.end()
d2 = re.search("Deliverable 2 – Reviewed design and implementation",text1)
d2s = d2.start()
d2e = d2.end()
d3 = re.search("Deliverable 3 – Demonstration of unit tests and final product",text1)
d3s = d3.start()
d3e = d3.end()
# d4 = re.search("Deliverable 4 – Final version",text1)
# d4s = d4.start()
# d4e = d4.end()
mid1 = re.search('Midterm Quiz',text1)
mid1s = mid1.start()
mid1e = mid1.end()
fin1 = re.search('Final Exam',text1)
fin1s = fin1.start()
fin1e = fin1.end()
proj1 = re.search('Project',text1)
proj1s = proj1.start()
proj1e=proj1.end()

#2nd syllabus
assignments = re.search('Assignments',text2)
assignmentss = assignments.start()
assignmentse = assignments.end()
mid2 = re.search('Midterm',text2)
mid2s = mid2.start()
mid2e = mid2.end()
fin2 = re.search('Final Exam',text2)
fin2s = fin2.start()
fin2e = fin2.end()

#3rd syllabus
labs = re.search('Labs',text3)
labss = labs.start()
labse = labs.end()

mid3 = re.search('Midterm 1',text3)
mid3s = mid3.start()
mid3e = mid3.end()

mid4 = re.search('Midterm 2',text3)
mid4s = mid4.start()
mid4e = mid4.end()

fin3 = re.search('Final Exam',text3)
fin3s = fin3.start()
fin3e = fin3.end()

# %%
#training data
import re
TRAIN_DATA = [(text1, {'entities': [(d1s, d1e, 'DELIVERABLE'), (d2s, d2e, 'DELIVERABLE'), (d3s, d3e, 'DELIVERABLE'), (mid1s, mid1e, 'EXAM'), (fin1s, fin1e, 'EXAM'), (proj1s, proj1e, 'DELIVERABLE')]})]
#      (text2, {
#         'entities': [(assignmentss, assignmentse, 'DELIVERABLE'),
#                      (mid2s, mid2e,'EXAM'),
#                      (fin2s, fin2e,'EXAM')]
#     }),
#     (text3, {
#         'entities': [(labss, labse, 'DELIVERABLE'),
#                      (mid3s, mid3e, 'EXAM'),
#                      (mid4s, mid4e, 'EXAM'),
#                      (fin3s, fin3e, 'EXAM')]
#     })
# ]

# %%
model = None
output_dir = Path("C:\\Users\\This PC\\Documents\\nlpModel")
n_iter=100

# %%
if model is not None:
    nlp=spacy.load(model)
    print("Loaded model '%s'" % model)
else:
    nlp = spacy.blank('en')
    print("Created blank model")
# Out:
# Created blank model

# %% [markdown]
# ## Setting up pipelines

# %%
# create the built-in pipeline components and add them to the pipeline
    # nlp.create_pipe works for built-ins that are registered with spaCy
if 'ner' not in nlp.pipe_names:
#     ner = nlp.create_pipe('ner')
    ner  = nlp.add_pipe('ner', last=True)
# otherwise, get it so we can add labels
else:
    ner = nlp.get_pipe('ner')

# %% [markdown]
# ## Training the recognizer
# https://github.com/dreji18/NER-Training-Spacy-3.0/blob/main/NER%20Training%20with%20Spacy%20v3%20Notebook.ipynb

# %%
import pandas as pd
import os
from tqdm import tqdm
import spacy
from spacy.tokens import DocBin

#nlp = spacy.blank("en") # load a new spacy model
nlp = spacy.load("en_core_web_sm") # load other spacy model

db = DocBin() # create a DocBin object

for text, annot in tqdm(TRAIN_DATA): # data in previous format
    doc = nlp.make_doc(text) # create doc object from text
    ents = []
    for start, end, label in annot["entities"]: # add character indexes
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents # label the text with the ents
    db.add(doc)

os.chdir(r'C:\Users\ghaza\nlp')
db.to_disk("./train.spacy") # save the docbin object
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 18.56it/s]

# %%
from spacy.training.example import Example

# %%
for _, annotations in TRAIN_DATA:
    for ent in annotations.get('entities'):
        ner.add_label(ent[2])

    # get names of other pipes to disable them during training
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']
with nlp.disable_pipes(*other_pipes):  # only train NER
    optimizer = nlp.create_optimizer()
    for itn in range(n_iter):
        random.shuffle(TRAIN_DATA)
        losses = {}
        for batch in spacy.util.minibatch(TRAIN_DATA, size=2):
            for text, annotations in batch:
                # create Example
                doc = nlp.make_doc(text)
                example = Example.from_dict(doc, annotations)
                # Update the model
                nlp.update([example], losses=losses, drop=0.3)
        print(losses)
# Out:
# {'ner': 244.1837063971907}
# {'ner': 188.03289268910885}
# {'ner': 116.27878299443705}
# {'ner': 73.97142558924298}
# {'ner': 40.96640918944172}
# {'ner': 251.56771111488342}
# {'ner': 18.699288788004196}
# {'ner': 17.04613913733658}
# {'ner': 14.152561053682575}
# {'ner': 13.44074547624831}
# {'ner': 12.048751292129339}
# {'ner': 191.89951902627945}
# {'ner': 11.713544816966873}
# {'ner': 76.29837518930435}
# {'ner': 11.362349173366141}
# {'ner': 10.26420670471066}
# {'ner': 9.696923342942682}
# {'ner': 9.798278875529832}
# {'ner': 11.89803223751619}
# {'ner': 218.92183899879456}
# {'ner': 9.866843202871678}
# {'ner': 9.481373014300289}
# {'ner': 12.660168612514099}
# {'ner': 10.723930787377867}
# {'ner': 8.393642435297807}
# {'ner': 11.813081883796258}
# {'ner': 8.193504449715874}
# {'ner': 11.593498326061308}
# {'ner': 9.15772226043191}
# {'ner': 8.260434867957429}
# {'ner': 7.369965855427836}
# {'ner': 6.963521466197562}
# {'ner': 14.452382505127506}
# {'ner': 7.343401295581746}
# {'ner': 6.473071625685449}
# {'ner': 8.290711878302918}
# {'ner': 186.70586436986923}
# {'ner': 9.033031922010764}
# {'ner': 18.045340777326444}
# {'ner': 112.83921745419502}
# {'ner': 7.526074700821598}
# {'ner': 149.65080496531823}
# {'ner': 53.98291289206594}
# {'ner': 8.91558857288698}
# {'ner': 63.772476648674726}
# {'ner': 73.60854703187943}
# {'ner': 102.94155293266836}
# {'ner': 136.7008696630901}
# {'ner': 47.5320937782526}
# {'ner': 52.46896179826558}
# {'ner': 52.94445972369016}
# {'ner': 90.88884840666071}
# {'ner': 46.39329282925297}
# {'ner': 51.56962491199374}
# {'ner': 23.631749332654636}
# {'ner': 14.127956553187744}
# {'ner': 20.782538355379074}
# {'ner': 13.114566696045188}
# {'ner': 11.647105759230044}
# {'ner': 12.074806730697901}
# {'ner': 11.607121287713198}
# {'ner': 14.574243004755772}
# {'ner': 12.926588003128444}
# {'ner': 10.799185420803603}
# {'ner': 14.230675223482063}
# {'ner': 10.45706019125312}
# {'ner': 10.1466932861631}
# {'ner': 13.036886483163725}
# {'ner': 11.29227249776762}
# {'ner': 12.771840071832443}
# {'ner': 13.830343728422601}
# {'ner': 13.547127818207974}
# {'ner': 10.60970514874125}
# {'ner': 12.94722324737392}
# {'ner': 12.558001013721228}
# {'ner': 10.07572842744411}
# {'ner': 10.07828638516893}
# {'ner': 9.928842025625276}
# {'ner': 9.623346621344098}
# {'ner': 9.806677811449484}
# {'ner': 7.839221126084453}
# {'ner': 7.2779387173280305}
# {'ner': 7.432540628342359}
# {'ner': 9.064885024043981}
# {'ner': 6.872691390701905}
# {'ner': 6.227984299770469}
# {'ner': 6.128205768066447}
# {'ner': 5.641045139123516}
# {'ner': 2.745197832256033}
# {'ner': 4.813097635110562}
# {'ner': 3.496059500101227}
# {'ner': 3.306117386477507}
# {'ner': 2.604296595286189}
# {'ner': 2.2436692906195357}
# {'ner': 2.4623889269365913}
# {'ner': 1.478464640578147}
# {'ner': 0.8476127764213255}
# {'ner': 1.3269433019700791}
# {'ner': 0.543009425785622}
# {'ner': 0.5803060867405869}

# %% [markdown]
# ## Testing the trained model

# %%
# test the trained model
for text, _ in TRAIN_DATA:
    doc = nlp(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Entities [('Project', 'DELIVERABLE'), ('Deliverable 1 – Draft Design.', 'DELIVERABLE'), ('Deliverable 2 – Reviewed design and implementation', 'DELIVERABLE'), ('Deliverable 3 – Demonstration of unit tests and final product', 'DELIVERABLE'), ('Midterm Quiz', 'EXAM'), ('Final Exam', 'EXAM')]
# Tokens [(' \n  ', '', 2), ('1/9', '', 2), ('\n \n \n \n \n', '', 2), ('School', '', 2), ('of', '', 2), ('electrical', '', 2), ('Engineering', '', 2), ('\n', '', 2), ('and', '', 2), ('Computer', '', 2), ('Science', '', 2), (' ', '', 2), ('(', '', 2), ('EECS', '', 2), (')', '', 2), (' ', '', 2), ('École', '', 2), ('de', '', 2), ('
2), ('.', '', 2), (' ', '', 2), ('The', '', 2), ('course', '', 2), ('will', '', 2), ('focus', '', 2), ('on', '', 2), ('the', '', 2), ('design', '', 2), ('of', '', 2), ('a', '', 2), ('n', '', 2), ('embedded', '', 2), ('real', '', 2), ('-time', '', 2), ('system', '', 2), (' ', '', 2), ('which', '', 2), ('can', '', 2), ('be', '', 2), ('defined', '', 2), ('\n', '', 2), ('as', '', 2), (':', '', 2), ('\n', '', 2), ('Embedded', '', 2), ('real', '', 2), ('-time', '', 2), ('Systems', '', 2), ('are', '', 2), ('comprised', '', 2), ('of', '', 2), ('computer', '', 2), ('software', '', 2), ('/', '', 2), ('hardware', '', 2), ('components', '', 2), ('embedded', '', 2), ('\n', '', 2), ('into', '', 2), ('larger', '', 2), ('systems', '', 2), ('composed', '', 2), ('of', '', 2), ('other', '', 2), ('sub', '', 2), ('-syste ...

# %% [markdown]
# ## Save the Model

# %%
# save model to output directory
if output_dir is not None:
    output_dir = Path(r"C:\Users\ghaza\Documents\4910 proj\NLP-Experiment")
    if not output_dir.exists():
        output_dir.mkdir()
    nlp.to_disk(output_dir)
    print("Saved model to", output_dir)
# Out:
# Saved model to C:\Users\ghaza\Documents\4910 proj\NLP-Experiment

# %% [markdown]
# ## Test The Saved Model

# %%
# test the saved model
print("Loading from", output_dir)
nlp2 = spacy.load(output_dir)
for text, _ in TRAIN_DATA:
    doc = nlp2(text)
    print('Entities', [(ent.text, ent.label_) for ent in doc.ents])
    print('Tokens', [(t.text, t.ent_type_, t.ent_iob) for t in doc])
# Out:
# Loading from C:\Users\ghaza\Documents\4910 proj\NLP-Experiment
# Entities [('Project', 'DELIVERABLE'), ('Deliverable 1 – Draft Design.', 'DELIVERABLE'), ('Deliverable 2 – Reviewed design and implementation', 'DELIVERABLE'), ('Deliverable 3 – Demonstration of unit tests and final product', 'DELIVERABLE'), ('Midterm Quiz', 'EXAM'), ('Final Exam', 'EXAM')]
# Tokens [(' \n  ', '', 2), ('1/9', '', 2), ('\n \n \n \n \n', '', 2), ('School', '', 2), ('of', '', 2), ('electrical', '', 2), ('Engineering', '', 2), ('\n', '', 2), ('and', '', 2), ('Computer', '', 2), ('Science', '', 2), (' ', '', 2), ('(', '', 2), ('EECS', '', 2), (')', '', 2), (' ', '', 2), ('École', '', 2), ('de', '', 2), ('science', '', 2), ('informatique', '', 2), ('et', '', 2), ('\n', '', 2), ('de', '', 2), ('génie', '', 2), ('électrique', '', 2), (' ', '', 2), ('(', '', 2), ('SIGE', '', 2), (')', '', 2), ('  \n \n', '', 2), ('CEG4166', '', 2), ('/', '', 2), ('CSI4141', '', 2), (' \n', '', 2), ('Real', '', 2), ('Time', '', 2), ('Systems', '', 2), ('Design', '', 2), (' ', '', 2), ('(', '', 2), ('3', '', 2), (',', '', 2), ('1.5', '', 2), (',', '', 2), ('3', '', 2), (')', '', 2), ('\n', '', 2), ('Winter', '', 2), ('202', '', 2), ('3', '', 2), ('\n', '', 2), ('Instructor', '', 2), (' ', '', 2), ('Gilbert', '', 2), ('Arbez', '', 2), (' \n', '', 2), ('Email', '', 2), (' ', '', 2), ('garbez@uottawa.ca', '', 2), ('  \n', '', 2), ('MS', '', 2), ('Teams', '',